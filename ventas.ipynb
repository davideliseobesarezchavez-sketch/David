# %% [markdown]
# <a href="https://colab.research.google.com/github/davideliseobesarezchavez-sketch/David/blob/main/ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras

# %%
# Cargar el dataset Fashion MNIST
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Definir las etiquetas de las categorías
labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
          "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Explorar el dataset dibujando las primeras 20 imágenes
plt.figure(figsize=(14, 8))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(X_train[i], cmap="binary")
    plt.title(labels[y_train[i]])
    plt.axis("off")
plt.show()

# %%
# Normalizar los datos escalando los píxeles al rango [0, 1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print("Datos normalizados correctamente.")

# %%
# 1. Definir la arquitectura
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# 2. Compilar el modelo
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 3. Entrenar el modelo (10 épocas)
print("Iniciando entrenamiento...")
historial = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# %%
# Evaluar el modelo en el conjunto de prueba
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f'\n==================================================')
print(f'🎯 Precisión final en el conjunto de prueba: {test_acc * 100:.2f}%')
print(f'==================================================')
